# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
pd.options.mode.chained_assignment = None  # default='warn'

# %%
n_itt = 30

# %%
begin_drift = 2000
end_drift = 3000

# %%
OPTWIN_PATH = "" #<-- DEFINE OPTWIN PATH
RESULT_FILE1 = OPTWIN_PATH+"/MOA-Experiments/results/gradual_binary/"
RESULT_FILE2 = "_"
RESULT_FILE3 = "_gradual_binary"
RESULT_FILE4 = ".csv"

# %%
save_plot = False
SAVE_PLOTS_DIR="" #set path to save plot if save_plot=True

# %%
methods = []
avg_delays = []
avg_fps = []
avg_tps = []

# %% [markdown]
# # OPTWIN -r 0.1

# %%
method = "(OPTWIN-r0.1)"

# %%
drift_detection = []
for i in range(1,n_itt+1):
    RESULT_FILE = RESULT_FILE1+method+RESULT_FILE2+str(i)+RESULT_FILE3+RESULT_FILE4
    drift_detection.append(pd.read_csv(RESULT_FILE))

# %%
#get average from n_itt runs
drift_detection_concat =  pd.concat(drift_detection)
drift_detection_concat['delay detection (average)'] = drift_detection_concat['delay detection (average)'].replace('?',0.0).astype('float64')
drift_detection_avg = drift_detection_concat.groupby(drift_detection_concat.index).mean(numeric_only=True)
drift_detection_std = drift_detection_concat.groupby(drift_detection_concat.index).std()
drift_detection_avg
# Out:
#       learning evaluation instances  evaluation time (cpu seconds)  \
# 0                               1.0                       0.068999
# 1                               2.0                       0.081294
# 2                               3.0                       0.085223
# 3                               4.0                       0.088279
# 4                               5.0                       0.090847
# ...                             ...                            ...
# 9995                         9996.0                       3.697460
# 9996                         9997.0                       3.697805
# 9997                         9998.0                       3.698137
# 9998                         9999.0                       3.698489
# 9999                        10000.0                       3.698832
#
#       model cost (RAM-Hours)  learned instances  detected changes  \
# 0               5.097961e-11                1.0               0.0
# 1               6.006379e-11                2.0               0.0
# 2               6.296710e-11                3.0               0.0
# 3               6.522519e-11                4.0               0.0
# 4               6.712236e-11                5.0               0.0
# ...                      ...                ...               ...
# 9995            2.731865e-09             9996.0               2.5
# 9996            2.732120e-09             9997.0               2.5
# 9997            2.732366e-09             9998.0               2.5
# 9998            2.732625e-09             9999.0               2.5
# 9999            2.732880e-09            10000.0               2.5
#
#       detected warnings  prediction error (average)  true changes  \
# 0              0.000000                    0.000000           0.0
# 1              0.000000                    0.100000           0.0
# 2              0.000000                    0.155556           0.0
# 3              0.000000                    0.188889           0.0
# 4              0.000000                    0.211111           0.0
# ...                 ...                         ...           ...
# 9995           0.233333                    0.093997           1.0
# 9996           0.233333                    0.093988           1.0
# 9997           0.233333                    0.093978           1.0
# 9998           0.233333                    0.093969           1.0
# 9999           0.233333                    0.093960           1.0
#
#       delay detection (average)  true changes detected  input values  \
# 0                      0.000000                    0.0           0.2
# 1                      0.000000                    0.0           0.2
# 2                      0.000000                    0.0           0.2
# 3                      0.000000                    0.0           0.2
# 4                      0.000000                    0.0           0.2
# ...                         ...                    ...           ...
# 9995                 328.033333                    1.0           1.0
# 9996                 328.033333                    1.0           1.0
# 9997                 328.033333                    1.0           1.0
# 9998                 328.033333                    1.0           1.0
# 9999                 328.033333                    1.0           1.0
#
#       model training instances  model serialized size (bytes)
# 0                          1.0                         2856.0
# 1                          2.0                         2856.0
# 2                          3.0                         2856.0
# 3                          4.0                         2856.0
# 4                          5.0                         2856.0
# ...                        ...                            ...
# 9995                    9996.0                         2856.0
# 9996                    9997.0                         2856.0
# 9997                    9998.0                         2856.0
# 9998                    9999.0                         2856.0
# 9999                   10000.0                         2856.0
#
# [10000 rows x 13 columns]

# %%
#Avg Delay
avg_delay = drift_detection_avg['delay detection (average)'][drift_detection_avg.shape[0]-1]

# %%
# Real Drifts
drift_detection_avg['drift'] = drift_detection_avg['true changes'].diff()
drift_detection_avg['drift'][0] = 0.0
drift_detection_avg['drift'] = drift_detection_avg['drift'].shift(periods=1)
drift_detection_avg['drift'][0] = 0.0
df_filtered = drift_detection_avg[drift_detection_avg['drift'] != 0]
df_filtered
# Out:
#       learning evaluation instances  evaluation time (cpu seconds)  \
# 2000                         2001.0                       0.956369
#
#       model cost (RAM-Hours)  learned instances  detected changes  \
# 2000            7.066126e-10             2001.0               0.3
#
#       detected warnings  prediction error (average)  true changes  \
# 2000                0.0                    0.318913           1.0
#
#       delay detection (average)  true changes detected  input values  \
# 2000                        0.0                    0.0         0.201
#
#       model training instances  model serialized size (bytes)  drift
# 2000                    2001.0                         2856.0    1.0

# %%
#Drifts
real_drifts = []
false_drifts = []

for i in range(n_itt): 
    drift_detection[i]['drift_detected'] = drift_detection[i]['detected changes'].diff()
    drift_detection[i]['drift_detected'][0] = 0.0
    drift_detection[i]['drift_detected'] = drift_detection[i]['drift_detected'].shift(periods=1)
    drift_detection[i]['drift_detected'][0] = 0.0
    all_drifts = drift_detection[i][drift_detection[i]['drift_detected'] != 0].index
    
    first_after_end = True
    f_drifts = []
    true_drifts = []
    for drift in all_drifts:
        if drift < begin_drift:
            f_drifts.append(drift)
        elif drift < end_drift:
            true_drifts.append(drift)
        #elif first_after_end:
        #    true_drifts.append(drift)
        #    first_after_end = False
        else:
            f_drifts.append(drift)
    
    real_drifts.append(true_drifts)
    false_drifts.append(f_drifts)

# %%
methods.append(method)
avg_delays.append(avg_delay)
avg_fps.append(sum(len(lst) for lst in false_drifts) / len(false_drifts))
avg_tps.append(sum(len(lst) for lst in real_drifts) / len(real_drifts))

# %%
plt.figure(figsize=(6,2.5))
plt.rcParams.update({'font.size': 20})
plt.title(r'OPTWIN -$\rho$ 0.1', fontsize = 20)
plt.ylabel('Avg of binary input') 
#plt.xlabel('Stream datapoints') 
count = 0
for l in real_drifts[0]:
    count +=1
    if count == 1:
        plt.vlines(l, 0.2, 1, colors = "green", linewidth=1, linestyles = "dashed")
    else:
        plt.vlines(l, 0.2, 1, colors = "black", linewidth=1, linestyles = "dashed")
    #plt.text(l+100, 1, str(l), c = "black", fontsize = 10)
if len(false_drifts) > 0:
    for f in false_drifts[0]:
        plt.vlines(f, 0.2, 1, colors = "red", linewidth=1, linestyles = "dashed")
        #plt.text(f+100, 1, "error", c = "red", fontsize = 10)
fp = [len(i) for i in false_drifts]
if len(fp) > 0:
    fp = sum(fp)/len(fp)
else:
    fp = 0
plt.text(100, 0.03, "FP: " + str(round(avg_fps[-1],2)), c = "red", fontsize = 20)
plt.text(3000, 0.03, "Delay: " + str(round(avg_delays[-1],0)), c = "green", fontsize = 20)
plt.text(7500, 0.03, "TP: " + str(round(avg_tps[-1],2)), c = "black", fontsize = 20)

x1,x2,y1,y2 = plt.axis()
plt.axis((0,9999,0,1.1))

drift_detection_avg['input values'].plot()
if save_plot:
    plt.savefig(SAVE_PLOTS_DIR+"grad_b_optwin0.1.svg", bbox_inches="tight")

# %% [markdown]
# # OPTWIN -r 0.5

# %%
method = "(OPTWIN-r0.5)"

# %%
drift_detection = []
for i in range(1,n_itt+1):
    RESULT_FILE = RESULT_FILE1+method+RESULT_FILE2+str(i)+RESULT_FILE3+RESULT_FILE4
    drift_detection.append(pd.read_csv(RESULT_FILE))

# %%
#get average from n_itt runs
drift_detection_concat =  pd.concat(drift_detection)
drift_detection_concat['delay detection (average)'] = drift_detection_concat['delay detection (average)'].replace('?',0.0).astype('float64')
drift_detection_avg = drift_detection_concat.groupby(drift_detection_concat.index).mean(numeric_only=True)
drift_detection_std = drift_detection_concat.groupby(drift_detection_concat.index).std()
drift_detection_avg
# Out:
#       learning evaluation instances  evaluation time (cpu seconds)  \
# 0                               1.0                       0.002073
# 1                               2.0                       0.013111
# 2                               3.0                       0.016590
# 3                               4.0                       0.019529
# 4                               5.0                       0.022254
# ...                             ...                            ...
# 9995                         9996.0                       3.533355
# 9996                         9997.0                       3.533693
# 9997                         9998.0                       3.534026
# 9998                         9999.0                       3.534352
# 9999                        10000.0                       3.534684
#
#       model cost (RAM-Hours)  learned instances  detected changes  \
# 0               1.531684e-12                1.0          0.000000
# 1               9.686855e-12                2.0          0.000000
# 2               1.225783e-11                3.0          0.000000
# 3               1.442913e-11                4.0          0.000000
# 4               1.644220e-11                5.0          0.000000
# ...                      ...                ...               ...
# 9995            2.610617e-09             9996.0          2.533333
# 9996            2.610867e-09             9997.0          2.533333
# 9997            2.611113e-09             9998.0          2.533333
# 9998            2.611353e-09             9999.0          2.533333
# 9999            2.611598e-09            10000.0          2.533333
#
#       detected warnings  prediction error (average)  true changes  \
# 0              0.000000                    0.000000           0.0
# 1              0.000000                    0.100000           0.0
# 2              0.000000                    0.155556           0.0
# 3              0.000000                    0.188889           0.0
# 4              0.000000                    0.211111           0.0
# ...                 ...                         ...           ...
# 9995           4.366667                    0.094254           1.0
# 9996           4.366667                    0.094245           1.0
# 9997           4.366667                    0.094235           1.0
# 9998           4.366667                    0.094226           1.0
# 9999           4.366667                    0.094217           1.0
#
#       delay detection (average)  true changes detected  input values  \
# 0                           0.0                    0.0           0.2
# 1                           0.0                    0.0           0.2
# 2                           0.0                    0.0           0.2
# 3                           0.0                    0.0           0.2
# 4                           0.0                    0.0           0.2
# ...                         ...                    ...           ...
# 9995                      278.9                    1.0           1.0
# 9996                      278.9                    1.0           1.0
# 9997                      278.9                    1.0           1.0
# 9998                      278.9                    1.0           1.0
# 9999                      278.9                    1.0           1.0
#
#       model training instances  model serialized size (bytes)
# 0                          1.0                         2856.0
# 1                          2.0                         2856.0
# 2                          3.0                         2856.0
# 3                          4.0                         2856.0
# 4                          5.0                         2856.0
# ...                        ...                            ...
# 9995                    9996.0                         2856.0
# 9996                    9997.0                         2856.0
# 9997                    9998.0                         2856.0
# 9998                    9999.0                         2856.0
# 9999                   10000.0                         2856.0
#
# [10000 rows x 13 columns]

# %%
#Avg Delay
avg_delay = drift_detection_avg['delay detection (average)'][drift_detection_avg.shape[0]-1]

# %%
# Real Drifts
drift_detection_avg['drift'] = drift_detection_avg['true changes'].diff()
drift_detection_avg['drift'][0] = 0.0
drift_detection_avg['drift'] = drift_detection_avg['drift'].shift(periods=1)
drift_detection_avg['drift'][0] = 0.0
df_filtered = drift_detection_avg[drift_detection_avg['drift'] != 0]
df_filtered
# Out:
#       learning evaluation instances  evaluation time (cpu seconds)  \
# 2000                         2001.0                       0.827373
#
#       model cost (RAM-Hours)  learned instances  detected changes  \
# 2000            6.113042e-10             2001.0               0.1
#
#       detected warnings  prediction error (average)  true changes  \
# 2000                0.0                    0.320149           1.0
#
#       delay detection (average)  true changes detected  input values  \
# 2000                        0.0                    0.0         0.201
#
#       model training instances  model serialized size (bytes)  drift
# 2000                    2001.0                         2856.0    1.0

# %%
#Drifts
real_drifts = []
false_drifts = []

for i in range(n_itt): 
    drift_detection[i]['drift_detected'] = drift_detection[i]['detected changes'].diff()
    drift_detection[i]['drift_detected'][0] = 0.0
    drift_detection[i]['drift_detected'] = drift_detection[i]['drift_detected'].shift(periods=1)
    drift_detection[i]['drift_detected'][0] = 0.0
    all_drifts = drift_detection[i][drift_detection[i]['drift_detected'] != 0].index
    
    first_after_end = True
    f_drifts = []
    true_drifts = []
    for drift in all_drifts:
        if drift < begin_drift:
            f_drifts.append(drift)
        elif drift < end_drift:
            true_drifts.append(drift)
        #elif first_after_end:
        #    true_drifts.append(drift)
        #    first_after_end = False
        else:
            f_drifts.append(drift)
    
    real_drifts.append(true_drifts)
    false_drifts.append(f_drifts)

# %%
methods.append(method)
avg_delays.append(avg_delay)
avg_fps.append(sum(len(lst) for lst in false_drifts) / len(false_drifts))
avg_tps.append(sum(len(lst) for lst in real_drifts) / len(real_drifts))

# %%
plt.figure(figsize=(6,2.5))
plt.rcParams.update({'font.size': 20})
plt.title(r'OPTWIN -$\rho$ 0.5', fontsize = 20)
#plt.ylabel('Avg of binary input') 
#plt.xlabel('Stream datapoints') 
count = 0
for l in real_drifts[0]:
    count +=1
    if count == 1:
        plt.vlines(l, 0.2, 1, colors = "green", linewidth=1, linestyles = "dashed")
    else:
        plt.vlines(l, 0.2, 1, colors = "black", linewidth=1, linestyles = "dashed")
    #plt.text(l+100, 1, str(l), c = "black", fontsize = 10)
if len(false_drifts) > 0:
    for f in false_drifts[0]:
        plt.vlines(f, 0.2, 1, colors = "red", linewidth=1, linestyles = "dashed")
        #plt.text(f+100, 1, "error", c = "red", fontsize = 10)
fp = [len(i) for i in false_drifts]
if len(fp) > 0:
    fp = sum(fp)/len(fp)
else:
    fp = 0
plt.text(100, 0.03, "FP: " + str(round(avg_fps[-1],2)), c = "red", fontsize = 20)
plt.text(3000, 0.03, "Delay: " + str(round(avg_delays[-1],0)), c = "green", fontsize = 20)
plt.text(7500, 0.03, "TP: " + str(round(avg_tps[-1],2)), c = "black", fontsize = 20)

x1,x2,y1,y2 = plt.axis()
plt.axis((0,9999,0,1.1))

drift_detection_avg['input values'].plot()
if save_plot:
    plt.savefig(SAVE_PLOTS_DIR+"grad_b_optwin0.5.svg", bbox_inches="tight")

# %% [markdown]
# # OPTWIN -r 1.0

# %%
method = "(OPTWIN-r1.0)"

# %%
drift_detection = []
for i in range(1,n_itt+1):
    RESULT_FILE = RESULT_FILE1+method+RESULT_FILE2+str(i)+RESULT_FILE3+RESULT_FILE4
    drift_detection.append(pd.read_csv(RESULT_FILE))

# %%
#get average from n_itt runs
drift_detection_concat =  pd.concat(drift_detection)
drift_detection_concat['delay detection (average)'] = drift_detection_concat['delay detection (average)'].replace('?',0.0).astype('float64')
drift_detection_avg = drift_detection_concat.groupby(drift_detection_concat.index).mean(numeric_only=True)
drift_detection_std = drift_detection_concat.groupby(drift_detection_concat.index).std()
drift_detection_avg
# Out:
#       learning evaluation instances  evaluation time (cpu seconds)  \
# 0                               1.0                       0.069596
# 1                               2.0                       0.081286
# 2                               3.0                       0.085343
# 3                               4.0                       0.088715
# 4                               5.0                       0.091507
# ...                             ...                            ...
# 9995                         9996.0                       3.523841
# 9996                         9997.0                       3.524195
# 9997                         9998.0                       3.524565
# 9998                         9999.0                       3.524914
# 9999                        10000.0                       3.525245
#
#       model cost (RAM-Hours)  learned instances  detected changes  \
# 0               5.142088e-11                1.0          0.000000
# 1               6.005842e-11                2.0          0.000000
# 2               6.305544e-11                3.0          0.000000
# 3               6.554736e-11                4.0          0.000000
# 4               6.760978e-11                5.0          0.000000
# ...                      ...                ...               ...
# 9995            2.603587e-09             9996.0          2.266667
# 9996            2.603849e-09             9997.0          2.266667
# 9997            2.604122e-09             9998.0          2.266667
# 9998            2.604380e-09             9999.0          2.266667
# 9999            2.604625e-09            10000.0          2.266667
#
#       detected warnings  prediction error (average)  true changes  \
# 0              0.000000                    0.000000           0.0
# 1              0.000000                    0.100000           0.0
# 2              0.000000                    0.155556           0.0
# 3              0.000000                    0.188889           0.0
# 4              0.000000                    0.211111           0.0
# ...                 ...                         ...           ...
# 9995           4.333333                    0.093855           1.0
# 9996           4.333333                    0.093846           1.0
# 9997           4.333333                    0.093837           1.0
# 9998           4.333333                    0.093827           1.0
# 9999           4.333333                    0.093818           1.0
#
#       delay detection (average)  true changes detected  input values  \
# 0                      0.000000                    0.0           0.2
# 1                      0.000000                    0.0           0.2
# 2                      0.000000                    0.0           0.2
# 3                      0.000000                    0.0           0.2
# 4                      0.000000                    0.0           0.2
# ...                         ...                    ...           ...
# 9995                 317.033333                    1.0           1.0
# 9996                 317.033333                    1.0           1.0
# 9997                 317.033333                    1.0           1.0
# 9998                 317.033333                    1.0           1.0
# 9999                 317.033333                    1.0           1.0
#
#       model training instances  model serialized size (bytes)
# 0                          1.0                         2856.0
# 1                          2.0                         2856.0
# 2                          3.0                         2856.0
# 3                          4.0                         2856.0
# 4                          5.0                         2856.0
# ...                        ...                            ...
# 9995                    9996.0                         2856.0
# 9996                    9997.0                         2856.0
# 9997                    9998.0                         2856.0
# 9998                    9999.0                         2856.0
# 9999                   10000.0                         2856.0
#
# [10000 rows x 13 columns]

# %%
#Avg Delay
avg_delay = drift_detection_avg['delay detection (average)'][drift_detection_avg.shape[0]-1]

# %%
# Real Drifts
drift_detection_avg['drift'] = drift_detection_avg['true changes'].diff()
drift_detection_avg['drift'][0] = 0.0
drift_detection_avg['drift'] = drift_detection_avg['drift'].shift(periods=1)
drift_detection_avg['drift'][0] = 0.0
df_filtered = drift_detection_avg[drift_detection_avg['drift'] != 0]
df_filtered
# Out:
#       learning evaluation instances  evaluation time (cpu seconds)  \
# 2000                         2001.0                       1.005832
#
#       model cost (RAM-Hours)  learned instances  detected changes  \
# 2000            7.431580e-10             2001.0          0.066667
#
#       detected warnings  prediction error (average)  true changes  \
# 2000                0.0                     0.32015           1.0
#
#       delay detection (average)  true changes detected  input values  \
# 2000                        0.0                    0.0         0.201
#
#       model training instances  model serialized size (bytes)  drift
# 2000                    2001.0                         2856.0    1.0

# %%
#Drifts
real_drifts = []
false_drifts = []

for i in range(n_itt): 
    drift_detection[i]['drift_detected'] = drift_detection[i]['detected changes'].diff()
    drift_detection[i]['drift_detected'][0] = 0.0
    drift_detection[i]['drift_detected'] = drift_detection[i]['drift_detected'].shift(periods=1)
    drift_detection[i]['drift_detected'][0] = 0.0
    all_drifts = drift_detection[i][drift_detection[i]['drift_detected'] != 0].index
    
    first_after_end = True
    f_drifts = []
    true_drifts = []
    for drift in all_drifts:
        if drift < begin_drift:
            f_drifts.append(drift)
        elif drift < end_drift:
            true_drifts.append(drift)
        #elif first_after_end:
        #    true_drifts.append(drift)
        #    first_after_end = False
        else:
            f_drifts.append(drift)
    
    real_drifts.append(true_drifts)
    false_drifts.append(f_drifts)

# %%
methods.append(method)
avg_delays.append(avg_delay)
avg_fps.append(sum(len(lst) for lst in false_drifts) / len(false_drifts))
avg_tps.append(sum(len(lst) for lst in real_drifts) / len(real_drifts))

# %%
plt.figure(figsize=(6,2.5))
plt.rcParams.update({'font.size': 20})
plt.title(r'OPTWIN -$\rho$ 1.0', fontsize = 20)
plt.ylabel('Avg of binary input') 
#plt.xlabel('Stream datapoints') 
count = 0
for l in real_drifts[0]:
    count +=1
    if count == 1:
        plt.vlines(l, 0.2, 1, colors = "green", linewidth=1, linestyles = "dashed")
    else:
        plt.vlines(l, 0.2, 1, colors = "black", linewidth=1, linestyles = "dashed")
    #plt.text(l+100, 1, str(l), c = "black", fontsize = 10)
if len(false_drifts) > 0:
    for f in false_drifts[0]:
        plt.vlines(f, 0.2, 1, colors = "red", linewidth=1, linestyles = "dashed")
        #plt.text(f+100, 1, "error", c = "red", fontsize = 10)
fp = [len(i) for i in false_drifts]
if len(fp) > 0:
    fp = sum(fp)/len(fp)
else:
    fp = 0
plt.text(100, 0.03, "FP: " + str(round(avg_fps[-1],2)), c = "red", fontsize = 20)
plt.text(3000, 0.03, "Delay: " + str(round(avg_delays[-1],0)), c = "green", fontsize = 20)
plt.text(7500, 0.03, "TP: " + str(round(avg_tps[-1],2)), c = "black", fontsize = 20)

x1,x2,y1,y2 = plt.axis()
plt.axis((0,9999,0,1.1))

drift_detection_avg['input values'].plot()
if save_plot:
    plt.savefig(SAVE_PLOTS_DIR+"grad_b_optwin1.0.svg", bbox_inches="tight")

# %% [markdown]
# # ADWIN

# %%
method = "ADWINChangeDetector"

# %%
drift_detection = []
for i in range(1,n_itt+1):
    RESULT_FILE = RESULT_FILE1+method+RESULT_FILE2+str(i)+RESULT_FILE3+RESULT_FILE4
    drift_detection.append(pd.read_csv(RESULT_FILE))

# %%
#get average from n_itt runs
drift_detection_concat =  pd.concat(drift_detection)
drift_detection_concat['delay detection (average)'] = drift_detection_concat['delay detection (average)'].replace('?',0.0).astype('float64')
drift_detection_avg = drift_detection_concat.groupby(drift_detection_concat.index).mean(numeric_only=True)
drift_detection_std = drift_detection_concat.groupby(drift_detection_concat.index).std()
drift_detection_avg
# Out:
#       learning evaluation instances  evaluation time (cpu seconds)  \
# 0                               1.0                       0.001586
# 1                               2.0                       0.008617
# 2                               3.0                       0.010387
# 3                               4.0                       0.011989
# 4                               5.0                       0.013439
# ...                             ...                            ...
# 9995                         9996.0                       1.716704
# 9996                         9997.0                       1.716835
# 9997                         9998.0                       1.716966
# 9998                         9999.0                       1.717098
# 9999                        10000.0                       1.717220
#
#       model cost (RAM-Hours)  learned instances  detected changes  \
# 0               5.645244e-13                1.0          0.000000
# 1               3.067389e-12                2.0          0.000000
# 2               3.697602e-12                3.0          0.000000
# 3               4.267762e-12                4.0          0.000000
# 4               4.784029e-12                5.0          0.000000
# ...                      ...                ...               ...
# 9995            1.179177e-09             9996.0         13.733333
# 9996            1.179280e-09             9997.0         13.733333
# 9997            1.179384e-09             9998.0         13.733333
# 9998            1.179489e-09             9999.0         13.733333
# 9999            1.179585e-09            10000.0         13.733333
#
#       detected warnings  prediction error (average)  true changes  \
# 0                   0.0                    0.000000           0.0
# 1                   0.0                    0.100000           0.0
# 2                   0.0                    0.155556           0.0
# 3                   0.0                    0.188889           0.0
# 4                   0.0                    0.211111           0.0
# ...                 ...                         ...           ...
# 9995                0.0                    0.102442           1.0
# 9996                0.0                    0.102431           1.0
# 9997                0.0                    0.102421           1.0
# 9998                0.0                    0.102411           1.0
# 9999                0.0                    0.102401           1.0
#
#       delay detection (average)  true changes detected  input values  \
# 0                      0.000000                    0.0           0.2
# 1                      0.000000                    0.0           0.2
# 2                      0.000000                    0.0           0.2
# 3                      0.000000                    0.0           0.2
# 4                      0.000000                    0.0           0.2
# ...                         ...                    ...           ...
# 9995                 280.466667                    1.0           1.0
# 9996                 280.466667                    1.0           1.0
# 9997                 280.466667                    1.0           1.0
# 9998                 280.466667                    1.0           1.0
# 9999                 280.466667                    1.0           1.0
#
#       model training instances  model serialized size (bytes)
# 0                          1.0                         1376.0
# 1                          2.0                         1376.0
# 2                          3.0                         1376.0
# 3                          4.0                         1376.0
# 4                          5.0                         1376.0
# ...                        ...                            ...
# 9995                    9996.0                         3056.0
# 9996                    9997.0                         3056.0
# 9997                    9998.0                         3056.0
# 9998                    9999.0                         3056.0
# 9999                   10000.0                         3056.0
#
# [10000 rows x 13 columns]

# %%
#Avg Delay
avg_delay = drift_detection_avg['delay detection (average)'][drift_detection_avg.shape[0]-1]

# %%
# Real Drifts
drift_detection_avg['drift'] = drift_detection_avg['true changes'].diff()
drift_detection_avg['drift'][0] = 0.0
drift_detection_avg['drift'] = drift_detection_avg['drift'].shift(periods=1)
drift_detection_avg['drift'][0] = 0.0
df_filtered = drift_detection_avg[drift_detection_avg['drift'] != 0]
df_filtered
# Out:
#       learning evaluation instances  evaluation time (cpu seconds)  \
# 2000                         2001.0                        0.59592
#
#       model cost (RAM-Hours)  learned instances  detected changes  \
# 2000            3.664785e-10             2001.0               0.0
#
#       detected warnings  prediction error (average)  true changes  \
# 2000                0.0                    0.319813           1.0
#
#       delay detection (average)  true changes detected  input values  \
# 2000                        0.0                    0.0         0.201
#
#       model training instances  model serialized size (bytes)  drift
# 2000                    2001.0                         2720.0    1.0

# %%
#Drifts
real_drifts = []
false_drifts = []

for i in range(n_itt): 
    drift_detection[i]['drift_detected'] = drift_detection[i]['detected changes'].diff()
    drift_detection[i]['drift_detected'][0] = 0.0
    drift_detection[i]['drift_detected'] = drift_detection[i]['drift_detected'].shift(periods=1)
    drift_detection[i]['drift_detected'][0] = 0.0
    all_drifts = drift_detection[i][drift_detection[i]['drift_detected'] != 0].index
    
    first_after_end = True
    f_drifts = []
    true_drifts = []
    for drift in all_drifts:
        if drift < begin_drift:
            f_drifts.append(drift)
        elif drift < end_drift:
            true_drifts.append(drift)
        #elif first_after_end:
        #    true_drifts.append(drift)
        #    first_after_end = False
        else:
            f_drifts.append(drift)
    
    real_drifts.append(true_drifts)
    false_drifts.append(f_drifts)

# %%
methods.append(method)
avg_delays.append(avg_delay)
avg_fps.append(sum(len(lst) for lst in false_drifts) / len(false_drifts))
avg_tps.append(sum(len(lst) for lst in real_drifts) / len(real_drifts))

# %%
itt = 5
plt.figure(figsize=(6,2.5))
plt.rcParams.update({'font.size': 20})
plt.title('ADWIN', fontsize = 20)
#plt.ylabel('Avg of binary input') 
#plt.xlabel('Stream datapoints') 
count = 0
for l in real_drifts[itt]:
    count +=1
    if count == 1:
        plt.vlines(l, 0.2, 1, colors = "green", linewidth=1, linestyles = "dashed")
    else:
        plt.vlines(l, 0.2, 1, colors = "black", linewidth=1, linestyles = "dashed")
    #plt.text(l+100, 1, str(l), c = "black", fontsize = 10)
if len(false_drifts) > 0:
    for f in false_drifts[itt]:
        plt.vlines(f, 0.2, 1, colors = "red", linewidth=1, linestyles = "dashed")
        #plt.text(f+100, 1, "error", c = "red", fontsize = 10)
fp = [len(i) for i in false_drifts]
if len(fp) > 0:
    fp = sum(fp)/len(fp)
else:
    fp = 0
plt.text(100, 0.03, "FP: " + str(round(avg_fps[-1],2)), c = "red", fontsize = 20)
plt.text(3000, 0.03, "Delay: " + str(round(avg_delays[-1],0)), c = "green", fontsize = 20)
plt.text(7500, 0.03, "TP: " + str(round(avg_tps[-1],2)), c = "black", fontsize = 20)

x1,x2,y1,y2 = plt.axis()
plt.axis((0,9999,0,1.1))

drift_detection_avg['input values'].plot()
if save_plot:
    plt.savefig(SAVE_PLOTS_DIR+"grad_b_adwin.svg", bbox_inches="tight")

# %% [markdown]
# # DDM

# %%
method = "DDM"

# %%
drift_detection = []
for i in range(1,n_itt+1):
    RESULT_FILE = RESULT_FILE1+method+RESULT_FILE2+str(i)+RESULT_FILE3+RESULT_FILE4
    drift_detection.append(pd.read_csv(RESULT_FILE))

# %%
#get average from n_itt runs
drift_detection_concat =  pd.concat(drift_detection)
drift_detection_concat['delay detection (average)'] = drift_detection_concat['delay detection (average)'].replace('?',0.0).astype('float64')
drift_detection_avg = drift_detection_concat.groupby(drift_detection_concat.index).mean(numeric_only=True)
drift_detection_std = drift_detection_concat.groupby(drift_detection_concat.index).std()
drift_detection_avg
# Out:
#       learning evaluation instances  evaluation time (cpu seconds)  \
# 0                               1.0                       0.001161
# 1                               2.0                       0.008021
# 2                               3.0                       0.010136
# 3                               4.0                       0.012027
# 4                               5.0                       0.013801
# ...                             ...                            ...
# 9995                         9996.0                       1.520128
# 9996                         9997.0                       1.520257
# 9997                         9998.0                       1.520379
# 9998                         9999.0                       1.520499
# 9999                        10000.0                       1.520620
#
#       model cost (RAM-Hours)  learned instances  detected changes  \
# 0               4.492614e-13                1.0          0.000000
# 1               3.104154e-12                2.0          0.000000
# 2               3.922694e-12                3.0          0.000000
# 3               4.654606e-12                4.0          0.000000
# 4               5.341095e-12                5.0          0.000000
# ...                      ...                ...               ...
# 9995            5.883144e-10             9996.0          2.966667
# 9996            5.883641e-10             9997.0          2.966667
# 9997            5.884112e-10             9998.0          2.966667
# 9998            5.884578e-10             9999.0          2.966667
# 9999            5.885046e-10            10000.0          2.966667
#
#       detected warnings  prediction error (average)  true changes  \
# 0              0.000000                    0.000000           0.0
# 1              0.000000                    0.100000           0.0
# 2              0.000000                    0.155556           0.0
# 3              0.000000                    0.188889           0.0
# 4              0.000000                    0.211111           0.0
# ...                 ...                         ...           ...
# 9995           2.533333                    0.097006           1.0
# 9996           2.533333                    0.096997           1.0
# 9997           2.533333                    0.096987           1.0
# 9998           2.533333                    0.096977           1.0
# 9999           2.533333                    0.096968           1.0
#
#       delay detection (average)  true changes detected  input values  \
# 0                      0.000000                    0.0           0.2
# 1                      0.000000                    0.0           0.2
# 2                      0.000000                    0.0           0.2
# 3                      0.000000                    0.0           0.2
# 4                      0.000000                    0.0           0.2
# ...                         ...                    ...           ...
# 9995                 365.166667                    1.0           1.0
# 9996                 365.166667                    1.0           1.0
# 9997                 365.166667                    1.0           1.0
# 9998                 365.166667                    1.0           1.0
# 9999                 365.166667                    1.0           1.0
#
#       model training instances  model serialized size (bytes)
# 0                          1.0                         1496.0
# 1                          2.0                         1496.0
# 2                          3.0                         1496.0
# 3                          4.0                         1496.0
# 4                          5.0                         1496.0
# ...                        ...                            ...
# 9995                    9996.0                         1496.0
# 9996                    9997.0                         1496.0
# 9997                    9998.0                         1496.0
# 9998                    9999.0                         1496.0
# 9999                   10000.0                         1496.0
#
# [10000 rows x 13 columns]

# %%
#Avg Delay
avg_delay = drift_detection_avg['delay detection (average)'][drift_detection_avg.shape[0]-1]

# %%
# Real Drifts
drift_detection_avg['drift'] = drift_detection_avg['true changes'].diff()
drift_detection_avg['drift'][0] = 0.0
drift_detection_avg['drift'] = drift_detection_avg['drift'].shift(periods=1)
drift_detection_avg['drift'][0] = 0.0
df_filtered = drift_detection_avg[drift_detection_avg['drift'] != 0]
df_filtered
# Out:
#       learning evaluation instances  evaluation time (cpu seconds)  \
# 2000                         2001.0                       0.500355
#
#       model cost (RAM-Hours)  learned instances  detected changes  \
# 2000            1.936456e-10             2001.0               0.3
#
#       detected warnings  prediction error (average)  true changes  \
# 2000                0.3                    0.319338           1.0
#
#       delay detection (average)  true changes detected  input values  \
# 2000                        0.0                    0.0         0.201
#
#       model training instances  model serialized size (bytes)  drift
# 2000                    2001.0                         1496.0    1.0

# %%
#Drifts
real_drifts = []
false_drifts = []

for i in range(n_itt): 
    drift_detection[i]['drift_detected'] = drift_detection[i]['detected changes'].diff()
    drift_detection[i]['drift_detected'][0] = 0.0
    drift_detection[i]['drift_detected'] = drift_detection[i]['drift_detected'].shift(periods=1)
    drift_detection[i]['drift_detected'][0] = 0.0
    all_drifts = drift_detection[i][drift_detection[i]['drift_detected'] != 0].index
    
    first_after_end = True
    f_drifts = []
    true_drifts = []
    for drift in all_drifts:
        if drift < begin_drift:
            f_drifts.append(drift)
        elif drift < end_drift:
            true_drifts.append(drift)
        #elif first_after_end:
        #    true_drifts.append(drift)
        #    first_after_end = False
        else:
            f_drifts.append(drift)
    
    real_drifts.append(true_drifts)
    false_drifts.append(f_drifts)

# %%
methods.append(method)
avg_delays.append(avg_delay)
avg_fps.append(sum(len(lst) for lst in false_drifts) / len(false_drifts))
avg_tps.append(sum(len(lst) for lst in real_drifts) / len(real_drifts))

# %%
itt = 2
plt.figure(figsize=(6,2.5))
plt.rcParams.update({'font.size': 20})
plt.title(method, fontsize = 20)
#plt.ylabel('Avg of binary input') 
plt.xlabel('Stream datapoints') 
count = 0
for l in real_drifts[itt]:
    count +=1
    if count == 1:
        plt.vlines(l, 0.2, 1, colors = "green", linewidth=1, linestyles = "dashed")
    else:
        plt.vlines(l, 0.2, 1, colors = "black", linewidth=1, linestyles = "dashed")
    #plt.text(l+100, 1, str(l), c = "black", fontsize = 10)
if len(false_drifts) > 0:
    for f in false_drifts[itt]:
        plt.vlines(f, 0.2, 1, colors = "red", linewidth=1, linestyles = "dashed")
        #plt.text(f+100, 1, "error", c = "red", fontsize = 10)
fp = [len(i) for i in false_drifts]
if len(fp) > 0:
    fp = sum(fp)/len(fp)
else:
    fp = 0
plt.text(100, 0.03, "FP: " + str(round(avg_fps[-1],2)), c = "red", fontsize = 20)
plt.text(3000, 0.03, "Delay: " + str(round(avg_delays[-1],0)), c = "green", fontsize = 20)
plt.text(7500, 0.03, "TP: " + str(round(avg_tps[-1],2)), c = "black", fontsize = 20)

x1,x2,y1,y2 = plt.axis()
plt.axis((0,9999,0,1.1))

drift_detection_avg['input values'].plot()
if save_plot:
    plt.savefig(SAVE_PLOTS_DIR+"grad_b_ddm.svg", bbox_inches="tight")

# %% [markdown]
# # EDDM

# %%
method = "EDDM"

# %%
drift_detection = []
for i in range(1,n_itt+1):
    RESULT_FILE = RESULT_FILE1+method+RESULT_FILE2+str(i)+RESULT_FILE3+RESULT_FILE4
    drift_detection.append(pd.read_csv(RESULT_FILE))

# %%
#get average from n_itt runs
drift_detection_concat =  pd.concat(drift_detection)
drift_detection_concat['delay detection (average)'] = drift_detection_concat['delay detection (average)'].replace('?',0.0).astype('float64')
drift_detection_avg = drift_detection_concat.groupby(drift_detection_concat.index).mean(numeric_only=True)
drift_detection_std = drift_detection_concat.groupby(drift_detection_concat.index).std()
drift_detection_avg
# Out:
#       learning evaluation instances  evaluation time (cpu seconds)  \
# 0                               1.0                       0.001030
# 1                               2.0                       0.006574
# 2                               3.0                       0.008085
# 3                               4.0                       0.009664
# 4                               5.0                       0.010858
# ...                             ...                            ...
# 9995                         9996.0                       1.252533
# 9996                         9997.0                       1.252651
# 9997                         9998.0                       1.252770
# 9998                         9999.0                       1.252892
# 9999                        10000.0                       1.253016
#
#       model cost (RAM-Hours)  learned instances  detected changes  \
# 0               2.664186e-13                1.0          0.000000
# 1               1.700664e-12                2.0          0.000000
# 2               2.091500e-12                3.0          0.000000
# 3               2.500127e-12                4.0          0.000000
# 4               2.808886e-12                5.0          0.000000
# ...                      ...                ...               ...
# 9995            3.240313e-10             9996.0         14.233333
# 9996            3.240617e-10             9997.0         14.233333
# 9997            3.240924e-10             9998.0         14.233333
# 9998            3.241240e-10             9999.0         14.233333
# 9999            3.241562e-10            10000.0         14.233333
#
#       detected warnings  prediction error (average)  true changes  \
# 0              0.000000                    0.000000           0.0
# 1              0.000000                    0.100000           0.0
# 2              0.000000                    0.244444           0.0
# 3              0.000000                    0.420833           0.0
# 4              0.000000                    0.613333           0.0
# ...                 ...                         ...           ...
# 9995           0.733333                    1.081189           1.0
# 9996           0.733333                    1.081080           1.0
# 9997           0.733333                    1.080972           1.0
# 9998           0.733333                    1.080864           1.0
# 9999           0.733333                    1.080756           1.0
#
#       delay detection (average)  true changes detected  input values  \
# 0                           0.0                    0.0           0.2
# 1                           0.0                    0.0           0.2
# 2                           0.0                    0.0           0.2
# 3                           0.0                    0.0           0.2
# 4                           0.0                    0.0           0.2
# ...                         ...                    ...           ...
# 9995                      148.1                    1.0           1.0
# 9996                      148.1                    1.0           1.0
# 9997                      148.1                    1.0           1.0
# 9998                      148.1                    1.0           1.0
# 9999                      148.1                    1.0           1.0
#
#       model training instances  model serialized size (bytes)
# 0                          1.0                         1000.0
# 1                          2.0                         1000.0
# 2                          3.0                         1000.0
# 3                          4.0                         1000.0
# 4                          5.0                         1000.0
# ...                        ...                            ...
# 9995                    9996.0                         1000.0
# 9996                    9997.0                         1000.0
# 9997                    9998.0                         1000.0
# 9998                    9999.0                         1000.0
# 9999                   10000.0                         1000.0
#
# [10000 rows x 13 columns]

# %%
#Avg Delay
avg_delay = drift_detection_avg['delay detection (average)'][drift_detection_avg.shape[0]-1]

# %%
# Real Drifts
drift_detection_avg['drift'] = drift_detection_avg['true changes'].diff()
drift_detection_avg['drift'][0] = 0.0
drift_detection_avg['drift'] = drift_detection_avg['drift'].shift(periods=1)
drift_detection_avg['drift'][0] = 0.0
df_filtered = drift_detection_avg[drift_detection_avg['drift'] != 0]
df_filtered
# Out:
#       learning evaluation instances  evaluation time (cpu seconds)  \
# 2000                         2001.0                       0.423161
#
#       model cost (RAM-Hours)  learned instances  detected changes  \
# 2000            1.094720e-10             2001.0          6.333333
#
#       detected warnings  prediction error (average)  true changes  \
# 2000           0.133333                    4.707519           1.0
#
#       delay detection (average)  true changes detected  input values  \
# 2000                        0.0                    0.0         0.201
#
#       model training instances  model serialized size (bytes)  drift
# 2000                    2001.0                         1000.0    1.0

# %%
#Drifts
real_drifts = []
false_drifts = []

for i in range(n_itt): 
    drift_detection[i]['drift_detected'] = drift_detection[i]['detected changes'].diff()
    drift_detection[i]['drift_detected'][0] = 0.0
    drift_detection[i]['drift_detected'] = drift_detection[i]['drift_detected'].shift(periods=1)
    drift_detection[i]['drift_detected'][0] = 0.0
    all_drifts = drift_detection[i][drift_detection[i]['drift_detected'] != 0].index
    
    first_after_end = True
    f_drifts = []
    true_drifts = []
    for drift in all_drifts:
        if drift < begin_drift:
            f_drifts.append(drift)
        elif drift < end_drift:
            true_drifts.append(drift)
        #elif first_after_end:
        #    true_drifts.append(drift)
        #    first_after_end = False
        else:
            f_drifts.append(drift)
    
    real_drifts.append(true_drifts)
    false_drifts.append(f_drifts)

# %%
methods.append(method)
avg_delays.append(avg_delay)
avg_fps.append(sum(len(lst) for lst in false_drifts) / len(false_drifts))
avg_tps.append(sum(len(lst) for lst in real_drifts) / len(real_drifts))

# %%
itt = 0
plt.figure(figsize=(6,2.5))
plt.rcParams.update({'font.size': 20})
plt.title(method, fontsize = 20)
#plt.ylabel('Avg of binary input') 
#plt.xlabel('Stream datapoints') 
count = 0
for l in real_drifts[itt]:
    count +=1
    if count == 1:
        plt.vlines(l, 0.2, 1, colors = "green", linewidth=1, linestyles = "dashed")
    else:
        plt.vlines(l, 0.2, 1, colors = "black", linewidth=1, linestyles = "dashed")
    #plt.text(l+100, 1, str(l), c = "black", fontsize = 10)
if len(false_drifts) > 0:
    for f in false_drifts[itt]:
        plt.vlines(f, 0.2, 1, colors = "red", linewidth=1, linestyles = "dashed")
        #plt.text(f+100, 1, "error", c = "red", fontsize = 10)
fp = [len(i) for i in false_drifts]
if len(fp) > 0:
    fp = sum(fp)/len(fp)
else:
    fp = 0
plt.text(100, 0.03, "FP: " + str(round(avg_fps[-1],2)), c = "red", fontsize = 20)
plt.text(3000, 0.03, "Delay: " + str(round(avg_delays[-1],0)), c = "green", fontsize = 20)
plt.text(7500, 0.03, "TP: " + str(round(avg_tps[-1],2)), c = "black", fontsize = 20)

x1,x2,y1,y2 = plt.axis()
plt.axis((0,9999,0,1.1))

drift_detection_avg['input values'].plot()
if save_plot:
    plt.savefig(SAVE_PLOTS_DIR+"grad_b_eddm.svg", bbox_inches="tight")

# %% [markdown]
# # STEPD

# %%
method = "STEPD"

# %%
drift_detection = []
for i in range(1,n_itt+1):
    RESULT_FILE = RESULT_FILE1+method+RESULT_FILE2+str(i)+RESULT_FILE3+RESULT_FILE4
    drift_detection.append(pd.read_csv(RESULT_FILE))

# %%
#get average from n_itt runs
drift_detection_concat =  pd.concat(drift_detection)
drift_detection_concat['delay detection (average)'] = drift_detection_concat['delay detection (average)'].replace('?',0.0).astype('float64')
drift_detection_avg = drift_detection_concat.groupby(drift_detection_concat.index).mean(numeric_only=True)
drift_detection_std = drift_detection_concat.groupby(drift_detection_concat.index).std()
drift_detection_avg
# Out:
#       learning evaluation instances  evaluation time (cpu seconds)  \
# 0                               1.0                       0.001391
# 1                               2.0                       0.009175
# 2                               3.0                       0.011510
# 3                               4.0                       0.013329
# 4                               5.0                       0.015189
# ...                             ...                            ...
# 9995                         9996.0                       1.596142
# 9996                         9997.0                       1.596264
# 9997                         9998.0                       1.596385
# 9998                         9999.0                       1.596512
# 9999                        10000.0                       1.596641
#
#       model cost (RAM-Hours)  learned instances  detected changes  \
# 0               5.785322e-13                1.0          0.000000
# 1               3.816895e-12                2.0          0.000000
# 2               4.788026e-12                3.0          0.000000
# 3               5.544616e-12                4.0          0.000000
# 4               6.318581e-12                5.0          0.000000
# ...                      ...                ...               ...
# 9995            6.639802e-10             9996.0         10.366667
# 9996            6.640311e-10             9997.0         10.366667
# 9997            6.640813e-10             9998.0         10.366667
# 9998            6.641341e-10             9999.0         10.366667
# 9999            6.641880e-10            10000.0         10.366667
#
#       detected warnings  prediction error (average)  true changes  \
# 0              0.000000                    0.000000           0.0
# 1              0.000000                    0.100000           0.0
# 2              0.000000                    0.133333           0.0
# 3              0.000000                    0.150000           0.0
# 4              0.000000                    0.166667           0.0
# ...                 ...                         ...           ...
# 9995           3.866667                    0.807760           1.0
# 9996           3.866667                    0.807779           1.0
# 9997           3.866667                    0.807798           1.0
# 9998           3.866667                    0.807817           1.0
# 9999           3.866667                    0.807837           1.0
#
#       delay detection (average)  true changes detected  input values  \
# 0                      0.000000                    0.0           0.2
# 1                      0.000000                    0.0           0.2
# 2                      0.000000                    0.0           0.2
# 3                      0.000000                    0.0           0.2
# 4                      0.000000                    0.0           0.2
# ...                         ...                    ...           ...
# 9995                 180.733333                    1.0           1.0
# 9996                 180.733333                    1.0           1.0
# 9997                 180.733333                    1.0           1.0
# 9998                 180.733333                    1.0           1.0
# 9999                 180.733333                    1.0           1.0
#
#       model training instances  model serialized size (bytes)
# 0                          1.0                         1608.0
# 1                          2.0                         1608.0
# 2                          3.0                         1608.0
# 3                          4.0                         1608.0
# 4                          5.0                         1608.0
# ...                        ...                            ...
# 9995                    9996.0                         1608.0
# 9996                    9997.0                         1608.0
# 9997                    9998.0                         1608.0
# 9998                    9999.0                         1608.0
# 9999                   10000.0                         1608.0
#
# [10000 rows x 13 columns]

# %%
#Avg Delay
avg_delay = drift_detection_avg['delay detection (average)'][drift_detection_avg.shape[0]-1]

# %%
# Real Drifts
drift_detection_avg['drift'] = drift_detection_avg['true changes'].diff()
drift_detection_avg['drift'][0] = 0.0
drift_detection_avg['drift'] = drift_detection_avg['drift'].shift(periods=1)
drift_detection_avg['drift'][0] = 0.0
df_filtered = drift_detection_avg[drift_detection_avg['drift'] != 0]
df_filtered
# Out:
#       learning evaluation instances  evaluation time (cpu seconds)  \
# 2000                         2001.0                       0.544484
#
#       model cost (RAM-Hours)  learned instances  detected changes  \
# 2000            2.265005e-10             2001.0               0.7
#
#       detected warnings  prediction error (average)  true changes  \
# 2000           0.066667                    0.200283           1.0
#
#       delay detection (average)  true changes detected  input values  \
# 2000                        0.0                    0.0         0.201
#
#       model training instances  model serialized size (bytes)  drift
# 2000                    2001.0                         1608.0    1.0

# %%
#Drifts
real_drifts = []
false_drifts = []

for i in range(n_itt): 
    drift_detection[i]['drift_detected'] = drift_detection[i]['detected changes'].diff()
    drift_detection[i]['drift_detected'][0] = 0.0
    drift_detection[i]['drift_detected'] = drift_detection[i]['drift_detected'].shift(periods=1)
    drift_detection[i]['drift_detected'][0] = 0.0
    all_drifts = drift_detection[i][drift_detection[i]['drift_detected'] != 0].index
    
    first_after_end = True
    f_drifts = []
    true_drifts = []
    for drift in all_drifts:
        if drift < begin_drift:
            f_drifts.append(drift)
        elif drift < end_drift:
            true_drifts.append(drift)
        #elif first_after_end:
        #    true_drifts.append(drift)
        #    first_after_end = False
        else:
            f_drifts.append(drift)
    
    real_drifts.append(true_drifts)
    false_drifts.append(f_drifts)

# %%
methods.append(method)
avg_delays.append(avg_delay)
avg_fps.append(sum(len(lst) for lst in false_drifts) / len(false_drifts))
avg_tps.append(sum(len(lst) for lst in real_drifts) / len(real_drifts))

# %%
itt = 16
plt.figure(figsize=(6,2.5))
plt.rcParams.update({'font.size': 20})
plt.title(method, fontsize = 20)
plt.ylabel('Avg of binary input') 
plt.xlabel('Stream datapoints') 
count = 0
for l in real_drifts[itt]:
    count +=1
    if count == 1:
        plt.vlines(l, 0.2, 1, colors = "green", linewidth=1, linestyles = "dashed")
    else:
        plt.vlines(l, 0.2, 1, colors = "black", linewidth=1, linestyles = "dashed")
    #plt.text(l+100, 1, str(l), c = "black", fontsize = 10)
if len(false_drifts) > 0:
    for f in false_drifts[itt]:
        plt.vlines(f, 0.2, 1, colors = "red", linewidth=1, linestyles = "dashed")
        #plt.text(f+100, 1, "error", c = "red", fontsize = 10)
fp = [len(i) for i in false_drifts]
if len(fp) > 0:
    fp = sum(fp)/len(fp)
else:
    fp = 0
plt.text(100, 0.03, "FP: " + str(round(avg_fps[-1],2)), c = "red", fontsize = 20)
plt.text(3000, 0.03, "Delay: " + str(round(avg_delays[-1],0)), c = "green", fontsize = 20)
plt.text(7500, 0.03, "TP: " + str(round(avg_tps[-1],2)), c = "black", fontsize = 20)

x1,x2,y1,y2 = plt.axis()
plt.axis((0,9999,0,1.1))

drift_detection_avg['input values'].plot()
if save_plot:
    plt.savefig(SAVE_PLOTS_DIR+"grad_b_stepd.svg", bbox_inches="tight")

# %% [markdown]
# # EWMAChartDM

# %%
method = "EWMAChartDM"

# %%
drift_detection = []
for i in range(1,n_itt+1):
    RESULT_FILE = RESULT_FILE1+method+RESULT_FILE2+str(i)+RESULT_FILE3+RESULT_FILE4
    drift_detection.append(pd.read_csv(RESULT_FILE))

# %%
#get average from n_itt runs
drift_detection_concat =  pd.concat(drift_detection)
drift_detection_concat['delay detection (average)'] = drift_detection_concat['delay detection (average)'].replace('?',0.0).astype('float64')
drift_detection_avg = drift_detection_concat.groupby(drift_detection_concat.index).mean(numeric_only=True)
drift_detection_std = drift_detection_concat.groupby(drift_detection_concat.index).std()
drift_detection_avg
# Out:
#       learning evaluation instances  evaluation time (cpu seconds)  \
# 0                               1.0                       0.001110
# 1                               2.0                       0.007715
# 2                               3.0                       0.009445
# 3                               4.0                       0.011009
# 4                               5.0                       0.012520
# ...                             ...                            ...
# 9995                         9996.0                       1.495393
# 9996                         9997.0                       1.495517
# 9997                         9998.0                       1.495660
# 9998                         9999.0                       1.495806
# 9999                        10000.0                       1.495944
#
#       model cost (RAM-Hours)  learned instances  detected changes  \
# 0               3.744200e-13                1.0          0.000000
# 1               2.602510e-12                2.0          0.000000
# 2               3.186129e-12                3.0          0.000000
# 3               3.713749e-12                4.0          0.000000
# 4               4.223479e-12                5.0          0.000000
# ...                      ...                ...               ...
# 9995            5.044645e-10             9996.0          7.333333
# 9996            5.045063e-10             9997.0          7.333333
# 9997            5.045544e-10             9998.0          7.333333
# 9998            5.046037e-10             9999.0          7.333333
# 9999            5.046505e-10            10000.0          7.333333
#
#       detected warnings  prediction error (average)  true changes  \
# 0              0.000000                    0.000000           0.0
# 1              0.000000                    0.100000           0.0
# 2              0.000000                    0.155556           0.0
# 3              0.000000                    0.188889           0.0
# 4              0.000000                    0.211111           0.0
# ...                 ...                         ...           ...
# 9995           8.866667                    0.134484           1.0
# 9996           8.866667                    0.134472           1.0
# 9997           8.866667                    0.134461           1.0
# 9998           8.866667                    0.134449           1.0
# 9999           8.866667                    0.134437           1.0
#
#       delay detection (average)  true changes detected  input values  \
# 0                           0.0                    0.0           0.2
# 1                           0.0                    0.0           0.2
# 2                           0.0                    0.0           0.2
# 3                           0.0                    0.0           0.2
# 4                           0.0                    0.0           0.2
# ...                         ...                    ...           ...
# 9995                      117.6                    1.0           1.0
# 9996                      117.6                    1.0           1.0
# 9997                      117.6                    1.0           1.0
# 9998                      117.6                    1.0           1.0
# 9999                      117.6                    1.0           1.0
#
#       model training instances  model serialized size (bytes)
# 0                          1.0                         1304.0
# 1                          2.0                         1304.0
# 2                          3.0                         1304.0
# 3                          4.0                         1304.0
# 4                          5.0                         1304.0
# ...                        ...                            ...
# 9995                    9996.0                         1304.0
# 9996                    9997.0                         1304.0
# 9997                    9998.0                         1304.0
# 9998                    9999.0                         1304.0
# 9999                   10000.0                         1304.0
#
# [10000 rows x 13 columns]

# %%
#Avg Delay
avg_delay = drift_detection_avg['delay detection (average)'][drift_detection_avg.shape[0]-1]

# %%
# Real Drifts
drift_detection_avg['drift'] = drift_detection_avg['true changes'].diff()
drift_detection_avg['drift'][0] = 0.0
drift_detection_avg['drift'] = drift_detection_avg['drift'].shift(periods=1)
drift_detection_avg['drift'][0] = 0.0
df_filtered = drift_detection_avg[drift_detection_avg['drift'] != 0]
df_filtered
# Out:
#       learning evaluation instances  evaluation time (cpu seconds)  \
# 2000                         2001.0                       0.501009
#
#       model cost (RAM-Hours)  learned instances  detected changes  \
# 2000            1.690132e-10             2001.0          5.366667
#
#       detected warnings  prediction error (average)  true changes  \
# 2000           0.033333                    0.318612           1.0
#
#       delay detection (average)  true changes detected  input values  \
# 2000                        0.0                    0.0         0.201
#
#       model training instances  model serialized size (bytes)  drift
# 2000                    2001.0                         1304.0    1.0

# %%
#Drifts
real_drifts = []
false_drifts = []

for i in range(n_itt): 
    drift_detection[i]['drift_detected'] = drift_detection[i]['detected changes'].diff()
    drift_detection[i]['drift_detected'][0] = 0.0
    drift_detection[i]['drift_detected'] = drift_detection[i]['drift_detected'].shift(periods=1)
    drift_detection[i]['drift_detected'][0] = 0.0
    all_drifts = drift_detection[i][drift_detection[i]['drift_detected'] != 0].index
    
    first_after_end = True
    f_drifts = []
    true_drifts = []
    for drift in all_drifts:
        if drift < begin_drift:
            f_drifts.append(drift)
        elif drift < end_drift:
            true_drifts.append(drift)
        #elif first_after_end:
        #    true_drifts.append(drift)
        #    first_after_end = False
        else:
            f_drifts.append(drift)
    
    real_drifts.append(true_drifts)
    false_drifts.append(f_drifts)

# %%
methods.append(method)
avg_delays.append(avg_delay)
avg_fps.append(sum(len(lst) for lst in false_drifts) / len(false_drifts))
avg_tps.append(sum(len(lst) for lst in real_drifts) / len(real_drifts))

# %%
itt = 13
plt.figure(figsize=(6,2.5))
plt.rcParams.update({'font.size': 20})
plt.title('ECDD', fontsize = 20)
#plt.ylabel('Avg of binary input') 
plt.xlabel('Stream datapoints') 
count = 0
for l in real_drifts[itt]:
    count +=1
    if count == 1:
        plt.vlines(l, 0.2, 1, colors = "green", linewidth=1, linestyles = "dashed")
    else:
        plt.vlines(l, 0.2, 1, colors = "black", linewidth=1, linestyles = "dashed")
    #plt.text(l+100, 1, str(l), c = "black", fontsize = 10)
if len(false_drifts) > 0:
    for f in false_drifts[itt]:
        plt.vlines(f, 0.2, 1, colors = "red", linewidth=1, linestyles = "dashed")
        #plt.text(f+100, 1, "error", c = "red", fontsize = 10)
fp = [len(i) for i in false_drifts]
if len(fp) > 0:
    fp = sum(fp)/len(fp)
else:
    fp = 0
plt.text(100, 0.03, "FP: " + str(round(avg_fps[-1],2)), c = "red", fontsize = 20)
plt.text(3000, 0.03, "Delay: " + str(round(avg_delays[-1],0)), c = "green", fontsize = 20)
plt.text(7500, 0.03, "TP: " + str(round(avg_tps[-1],2)), c = "black", fontsize = 20)

x1,x2,y1,y2 = plt.axis()
plt.axis((0,9999,0,1.1))

drift_detection_avg['input values'].plot()
if save_plot:
    plt.savefig(SAVE_PLOTS_DIR+"grad_b_ecdd.svg", bbox_inches="tight")

# %%
methods
# Out:
# ['(OPTWIN-r0.1)',
#  '(OPTWIN-r0.5)',
#  '(OPTWIN-r1.0)',
#  'ADWINChangeDetector',
#  'DDM',
#  'EDDM',
#  'STEPD',
#  'EWMAChartDM']

# %%
avg_delays
# Out:
# [328.03333333333336,
#  278.9,
#  317.03333333333336,
#  280.46666666666664,
#  365.1666666666667,
#  148.1,
#  180.73333333333332,
#  117.6]

# %%
avg_fps
# Out:
# [0.3,
#  0.1,
#  0.06666666666666667,
#  1.6333333333333333,
#  0.36666666666666664,
#  6.333333333333333,
#  8.0,
#  5.366666666666666]

# %%
avg_tps
# Out:
# [2.2,
#  2.433333333333333,
#  2.2,
#  12.1,
#  2.6,
#  7.9,
#  2.3666666666666667,
#  1.9666666666666666]
