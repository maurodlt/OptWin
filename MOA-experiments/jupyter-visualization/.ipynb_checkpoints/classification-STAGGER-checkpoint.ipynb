# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Run experiments
#
# cd OPTWIN_PATH/Moa-Experiments/scripts/
#
# ./classification_experiments.sh

# %%
pd.options.mode.chained_assignment = None  # default='warn'

# %%
n_itt = 30

# %%
OPTWIN_PATH = "" #<-- DEFINE OPTWIN PATH
RESULT_FILE1 = OPTWIN_PATH+"/MOA-Experiments/results/nb_results/"
RESULT_FILE1 += "naive_bayes_STAGGERGenerator_"
RESULT_FILE2 = ".csv"

# %%
save_plot = False
PLOT_SAVE_DIR="" #set path to save plot if save_plot=True

# %%
def plot_drifts(method, df, true_positives, false_positives, x_axis, y_axis, legend, separate_legend):
    drifts = [20000,40000,60000,80000]
    #df['classifications_correct_(percent)']
    plt.rcParams.update({'font.size': 20})
    plt.figure(figsize=(6,2.5))
    plt.title(method, fontsize = 20)
    if y_axis:
        plt.ylabel('Accuracy') 
    if x_axis:
        plt.xlabel('Stream datapoints') 
    
    for d in drifts:
        plt.vlines(d, 80, 98, colors = "black", linewidth=2)
        #plt.text(d+500, 80, "Drift", c = "black", fontsize = 10)
    
    for tp in true_positives:
        plt.vlines(tp, 80, 99, colors = "green", linewidth=1, linestyles = "dashed")
        #plt.text(d+500, 80, "Drift", c = "blue", fontsize = 10)
    
    
    for fp in false_positives:
        plt.vlines(fp, 99, 100, colors = "red", linewidth=1, linestyles = "dashed")
        #plt.text(d+500, 80, "Drift", c = "blue", fontsize = 10)
    
    if len(drifts) > 0 : plt.vlines(drifts[0], 80, 98, colors = "black", linewidth=2, label = "Drift")
    if len(true_positives) > 0 : plt.vlines(true_positives[0], 80, 99, colors = "green", linewidth=1, linestyles = "dashed", label = "TP")
    if len(false_positives) > 0 : plt.vlines(false_positives[0], 99, 100, colors = "red", linewidth=1, linestyles = "dashed", label = "FP")
    
    
    x1,x2,y1,y2 = plt.axis()
    plt.axis((1,99999,96,100))
    #plt.rcParams.update({'font.size': 30})
    
    df['classifications_correct_(percent)'].plot(label='')
    
    if legend:
        plt.legend(loc="lower right")
        if save_plot:
            plt.savefig(PLOT_SAVE_DIR+'agrawal_'+method.replace(' ', '')+'.svg', bbox_inches="tight") #save plot
        plt.show()
    elif separate_legend:
        plt.legend()
        ax = plt.gca()
        legend_handles, legend_labels = ax.get_legend_handles_labels() #get legends
        plt.gca().legend_ = None #remove legends
        if save_plot:
            plt.savefig(PLOT_SAVE_DIR+'agrawal_'+method.replace(' ', '')+'.svg', bbox_inches="tight") #save plot
        plt.show() #print plot without legends
        
        legend_figure = plt.figure() 
        plt.plot([], []) #create new empty plot
        plt.legend(legend_handles, legend_labels, loc='upper center', bbox_to_anchor=(0, 0), ncol=3) #add legends
        plt.axis('off') #remove axis
        plt.subplots_adjust(top=0.01, bottom=0, left=0.1, right=0.2)  # Reduce image size
        if save_plot:
            plt.savefig(PLOT_SAVE_DIR+'legend.svg', bbox_inches="tight") #save lagend

    else:
        if save_plot:
            plt.savefig(PLOT_SAVE_DIR+'stagger_'+method.replace(' ', '')+'.svg', bbox_inches="tight") #save plot
        plt.show()

# %%
def identify_metrics(method, n_itt, name, itt, x_axis, y_axis, legend, separate_legend):
    output = {}
    output['method'] = method
    #open n_itt results
    drift_detection = []
    for i in range(1,n_itt+1):
        RESULT_FILE = RESULT_FILE1+method+"_"+str(i)+"_"+str(drift_window)+RESULT_FILE2
        df = pd.read_csv(RESULT_FILE, low_memory=False)
        df.columns = [c.replace(' ', '_') for c in df.columns] #remove spaces from column names
        drift_detection.append(df)
        
    #get avg and std from n_itt runs
    drift_detection_concat =  pd.concat(drift_detection)
    drift_detection_concat = drift_detection_concat.drop('Kappa_Statistic_(percent)', axis=1) #remove unused statistic
    drift_detection_concat = drift_detection_concat.drop('Kappa_Temporal_Statistic_(percent)', axis=1) #remove unused statistic
    drift_detection_concat = drift_detection_concat.drop('Kappa_M_Statistic_(percent)', axis=1) #remove unused statistic
    drift_detection_avg = drift_detection_concat.groupby(drift_detection_concat.index).mean(numeric_only=True)
    drift_detection_sdv = drift_detection_concat.groupby(drift_detection_concat.index).std()

    output['avg_accuracy'] = drift_detection_avg['classifications_correct_(percent)'][len(drift_detection_avg.index)-1]
    output['std_accuracy'] = drift_detection_sdv['classifications_correct_(percent)'][len(drift_detection_sdv.index)-1]
    
    output['avg_cpu'] = drift_detection_avg['evaluation_time_(cpu_seconds)'][len(drift_detection_avg.index)-1]
    output['std_cpu'] = drift_detection_sdv['evaluation_time_(cpu_seconds)'][len(drift_detection_sdv.index)-1]
    
    output['avg_ram']  = drift_detection_avg['model_cost_(RAM-Hours)'][len(drift_detection_avg.index)-1]
    output['std_ram']  = drift_detection_sdv['model_cost_(RAM-Hours)'][len(drift_detection_sdv.index)-1]
    
    #get drift delays & true and false positives
    avg_delays = []
    false_positives = []
    true_positives = []
    list_true_positives = [] #index of true positives
    list_false_positives = [] #index of false_positives
    for i in range(len(drift_detection)):
        streams = []
        streams.append(drift_detection[i]['Change_detected'].iloc[:20000])
        streams.append(drift_detection[i]['Change_detected'].iloc[20000:40000])
        streams.append(drift_detection[i]['Change_detected'].iloc[40000:60000])
        streams.append(drift_detection[i]['Change_detected'].iloc[60000:80000])
        streams.append(drift_detection[i]['Change_detected'].iloc[80000:])
        
        

        delay = []
        fp = streams[0].sum()
        tp = 0
        l_true_positives = []
        l_false_positives = streams[0].eq(1).index[streams[0].eq(1)].tolist()
        for s in streams[1:]:
            if s.sum() >= 1: #drift identified in stream interval
                drifts_list = s.eq(1).index[s.eq(1)].tolist()
                tp += 1 #first drift is true
                l_true_positives.extend([drifts_list[0]])
                fp += s.sum() - 1 #other drifts are false positives
                l_false_positives.extend(drifts_list[1:])
                drift_init = s.index[0]
                drift_identified = s[s > 0].index[0]
                delay.append(drift_identified - drift_init)

        if len(delay) > 0:
            avg_delay = sum(delay) / len(delay)
            avg_delays.append(avg_delay)
        false_positives.append(fp)
        true_positives.append(tp)
        list_true_positives.append(l_true_positives)
        list_false_positives.append(l_false_positives)
    
    if len(avg_delays) > 0:
        output['avg_delay'] = sum(avg_delays) / len(avg_delays)
    else:
        output['avg_delay'] = 0
    output['std_delay'] = np.std(avg_delays)
    
    output['avg_fp'] = sum(false_positives) / len(false_positives)
    output['std_fp'] = np.std(false_positives)
    
    output['avg_tp'] = sum(true_positives) / len(true_positives)
    output['std_tp'] = np.std(true_positives)
    
    plot_drifts(name, drift_detection[itt], list_true_positives[itt], list_false_positives[itt], x_axis, y_axis, legend, separate_legend)
    
    return output

# %% [markdown]
# # ABRUPT DRIFT

# %%
drift_window = 1

# %% [markdown]
# ### OPTWIN -r 0.1

# %%
method = "(OPTWIN-r0.1)"
itt = 1
name = r'OPTWIN -$\rho$ 0.1'
optwin01_output = identify_metrics(method, n_itt, name, itt, False, True, False, False)
optwin01_output
# Out:
# {'method': '(OPTWIN-r0.1)',
#  'avg_accuracy': 99.9645,
#  'std_accuracy': 0.011681845626502778,
#  'avg_cpu': 48.528414,
#  'std_cpu': 8.506004128824285,
#  'avg_ram': 4.720412001462189e-08,
#  'std_ram': 8.273888778395855e-09,
#  'avg_delay': 0.7583333333333333,
#  'std_delay': 0.5419230162629702,
#  'avg_fp': 0.26666666666666666,
#  'std_fp': 0.5120763831912406,
#  'avg_tp': 4.0,
#  'std_tp': 0.0}

# %% [markdown]
# ### OPTWIN -r 0.5

# %%
method = "(OPTWIN-r0.5)"
itt = 1
name = r'OPTWIN -$\rho$ 0.5'
optwin05_output = identify_metrics(method, n_itt, name, itt, False, False, False, False)
optwin05_output
# Out:
# {'method': '(OPTWIN-r0.5)',
#  'avg_accuracy': 99.9637,
#  'std_accuracy': 0.012473834684015955,
#  'avg_cpu': 47.87552193333333,
#  'std_cpu': 8.748246092640576,
#  'avg_ram': 4.656914999094611e-08,
#  'std_ram': 8.509533771257444e-09,
#  'avg_delay': 0.7166666666666667,
#  'std_delay': 0.5273097339852125,
#  'avg_fp': 0.43333333333333335,
#  'std_fp': 0.7608474807008885,
#  'avg_tp': 4.0,
#  'std_tp': 0.0}

# %% [markdown]
# ### OPTWIN -r 1.0

# %%
method = "(OPTWIN-r1.0)"
itt = 0
name = r'OPTWIN -$\rho$ 1.0'
optwin10_output = identify_metrics(method, n_itt, name, itt, False, True, False, False)
optwin10_output
# Out:
# {'method': '(OPTWIN-r1.0)',
#  'avg_accuracy': 99.96193333333333,
#  'std_accuracy': 0.01362789566403749,
#  'avg_cpu': 47.70423973333333,
#  'std_cpu': 8.168141833262535,
#  'avg_ram': 4.640243243405383e-08,
#  'std_ram': 7.945239424274303e-09,
#  'avg_delay': 0.7166666666666667,
#  'std_delay': 0.5273097339852125,
#  'avg_fp': 0.6,
#  'std_fp': 0.916515138991168,
#  'avg_tp': 4.0,
#  'std_tp': 0.0}

# %% [markdown]
# ### ADWIN

# %%
method = "ADWINChangeDetector"
itt = 0
name = "ADWIN"
adwin_output = identify_metrics(method, n_itt, name, itt, False, False, False, False)
adwin_output
# Out:
# {'method': 'ADWINChangeDetector',
#  'avg_accuracy': 99.89026666666668,
#  'std_accuracy': 0.009457466794070349,
#  'avg_cpu': 47.046632466666665,
#  'std_cpu': 5.498917998702482,
#  'avg_ram': 4.8273396534155135e-08,
#  'std_ram': 5.6261415025823584e-09,
#  'avg_delay': 31.0,
#  'std_delay': 0.0,
#  'avg_fp': 0.3,
#  'std_fp': 0.6904105059069325,
#  'avg_tp': 4.0,
#  'std_tp': 0.0}

# %% [markdown]
# ### DDM

# %%
method = "DDM"
itt = 1
name = method
ddm_output = identify_metrics(method, n_itt, name, itt, False, True, False, False)
ddm_output
# Out:
# {'method': 'DDM',
#  'avg_accuracy': 99.9565,
#  'std_accuracy': 0.013446573720751573,
#  'avg_cpu': 44.2255747,
#  'std_cpu': 2.0590238628001942,
#  'avg_ram': 2.7480226927540065e-08,
#  'std_ram': 1.281329575141459e-09,
#  'avg_delay': 6.325,
#  'std_delay': 1.8179085968955278,
#  'avg_fp': 0.16666666666666666,
#  'std_fp': 0.521749194749951,
#  'avg_tp': 4.0,
#  'std_tp': 0.0}

# %% [markdown]
# ### EDDM

# %%
method = "EDDM"
itt = 0
name = method
eddm_output = identify_metrics(method, n_itt, name, itt, False, False, False, False)
eddm_output
# Out:
# {'method': 'EDDM',
#  'avg_accuracy': 99.87096666666666,
#  'std_accuracy': 0.0013767361035600782,
#  'avg_cpu': 41.1384719,
#  'std_cpu': 1.9989912003899977,
#  'avg_ram': 2.0263355514379417e-08,
#  'std_ram': 9.84626214914741e-10,
#  'avg_delay': 40.00833333333333,
#  'std_delay': 4.471429363811482,
#  'avg_fp': 0.0,
#  'std_fp': 0.0,
#  'avg_tp': 4.0,
#  'std_tp': 0.0}

# %% [markdown]
# ### STEPD

# %%
method = "STEPD"
itt = 0
name = method
stepd_output = identify_metrics(method, n_itt, name, itt, True, True, False, True)
stepd_output
# Out:
# {'method': 'STEPD',
#  'avg_accuracy': 98.7364,
#  'std_accuracy': 0.7961378584486303,
#  'avg_cpu': 47.040182933333334,
#  'std_cpu': 5.380078159055013,
#  'avg_ram': 3.069339549755269e-08,
#  'std_ram': 3.5176848886947556e-09,
#  'avg_delay': 17.391666666666666,
#  'std_delay': 72.21477466942312,
#  'avg_fp': 31.4,
#  'std_fp': 4.1036569057366385,
#  'avg_tp': 3.966666666666667,
#  'std_tp': 0.1795054935711501}

# %% [markdown]
# ### EWMAChartDM

# %%
method = "EWMAChartDM"
itt = 3
name = "ECDD"
EWMAChartDM_output = identify_metrics(method, n_itt, name, itt, True, False, False, False)
EWMAChartDM_output
# Out:
# {'method': 'EWMAChartDM',
#  'avg_accuracy': 99.96083333333333,
#  'std_accuracy': 0.014355302596730244,
#  'avg_cpu': 44.215680199999994,
#  'std_cpu': 1.7166800107277913,
#  'avg_ram': 2.5292314248366435e-08,
#  'std_ram': 9.921820098198891e-10,
#  'avg_delay': 0.7166666666666667,
#  'std_delay': 0.5273097339852125,
#  'avg_fp': 0.4666666666666667,
#  'std_fp': 0.8459051693633012,
#  'avg_tp': 4.0,
#  'std_tp': 0.0}

# %%
method = "moa.classifiers.rules.core.changedetection.NoChangeDetection"
itt = 0
name = "No Drift Detector"
no_output = identify_metrics(method, n_itt, name, itt, True, True, True, True)
no_output
# Out:
# /Users/mauro.dalleluccatosi/Documents/environments/tensair/lib/python3.9/site-packages/numpy/core/_methods.py:269: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /Users/mauro.dalleluccatosi/Documents/environments/tensair/lib/python3.9/site-packages/numpy/core/_methods.py:226: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# /Users/mauro.dalleluccatosi/Documents/environments/tensair/lib/python3.9/site-packages/numpy/core/_methods.py:261: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# {'method': 'moa.classifiers.rules.core.changedetection.NoChangeDetection',
#  'avg_accuracy': 66.30726666666666,
#  'std_accuracy': 0.15905170127402365,
#  'avg_cpu': 40.9344034,
#  'std_cpu': 2.0369053701223367,
#  'avg_ram': 1.9146235119139125e-08,
#  'std_ram': 9.527214904105616e-10,
#  'avg_delay': 0,
#  'std_delay': nan,
#  'avg_fp': 0.0,
#  'std_fp': 0.0,
#  'avg_tp': 0.0,
#  'std_tp': 0.0}

# %% [markdown]
# # GRADUAL DRIFT

# %%
drift_window = 1000

# %% [markdown]
# ### OPTWIN -r 0.1

# %%
method = "(OPTWIN-r0.1)"
itt = 0
name = method
optwin01_gradual_output = identify_metrics(method, n_itt, name, itt, True, True, True, True)
optwin01_gradual_output
# Out:
# {'method': '(OPTWIN-r0.1)',
#  'avg_accuracy': 98.71119999999999,
#  'std_accuracy': 0.08162082222502717,
#  'avg_cpu': 44.927876966666666,
#  'std_cpu': 0.6720071464678732,
#  'avg_ram': 4.371033309889965e-08,
#  'std_ram': 6.484794505273774e-10,
#  'avg_delay': 9620.652777777776,
#  'std_delay': 4812.176943513895,
#  'avg_fp': 6.533333333333333,
#  'std_fp': 1.2036980056845192,
#  'avg_tp': 3.566666666666667,
#  'std_tp': 0.4955356249106169}

# %% [markdown]
# ### OPTWIN -r 0.5

# %%
method = "(OPTWIN-r0.5)"
itt = 0
name = method
optwin05_gradual_output = identify_metrics(method, n_itt, name, itt, True, True, True, True)
optwin05_gradual_output
# Out:
# {'method': '(OPTWIN-r0.5)',
#  'avg_accuracy': 98.50823333333332,
#  'std_accuracy': 0.15545343760871908,
#  'avg_cpu': 44.3593144,
#  'std_cpu': 1.254026192191887,
#  'avg_ram': 4.3196429067739805e-08,
#  'std_ram': 1.2226782165539047e-09,
#  'avg_delay': 12687.849999999999,
#  'std_delay': 4036.7959557238146,
#  'avg_fp': 8.833333333333334,
#  'std_fp': 1.4161763857498668,
#  'avg_tp': 3.1,
#  'std_tp': 0.3}

# %% [markdown]
# ### OPTWIN -r 1.0

# %%
method = "(OPTWIN-r1.0)"
itt = 0
name = method
optwin10_gradual_output = identify_metrics(method, n_itt, name, itt, True, True, True, True)
optwin10_gradual_output
# Out:
# {'method': '(OPTWIN-r1.0)',
#  'avg_accuracy': 98.35636666666666,
#  'std_accuracy': 0.31488853893723207,
#  'avg_cpu': 44.85243953333334,
#  'std_cpu': 0.6165020997184756,
#  'avg_ram': 4.3694765254855514e-08,
#  'std_ram': 5.917131882587194e-10,
#  'avg_delay': 9536.291666666666,
#  'std_delay': 4773.860074363983,
#  'avg_fp': 9.066666666666666,
#  'std_fp': 1.7113996870657913,
#  'avg_tp': 3.3333333333333335,
#  'std_tp': 0.4714045207910318}

# %% [markdown]
# ### ADWIN

# %%
method = "ADWINChangeDetector"
itt = 0
name = method
adwin_gradual_output = identify_metrics(method, n_itt, name, itt, True, True, True, True)
adwin_gradual_output
# Out:
# {'method': 'ADWINChangeDetector',
#  'avg_accuracy': 98.7371,
#  'std_accuracy': 0.05149245006593809,
#  'avg_cpu': 43.930546533333334,
#  'std_cpu': 2.3102407295171745,
#  'avg_ram': 4.4640305551734626e-08,
#  'std_ram': 2.3458230947657593e-09,
#  'avg_delay': 5412.333333333333,
#  'std_delay': 4105.21353800172,
#  'avg_fp': 32.666666666666664,
#  'std_fp': 3.0804040139061124,
#  'avg_tp': 3.8666666666666667,
#  'std_tp': 0.33993463423951903}

# %% [markdown]
# ### DDM

# %%
method = "DDM"
itt = 0
name = method
ddm_gradual_output = identify_metrics(method, n_itt, name, itt, True, True, True, True)
ddm_gradual_output
# Out:
# {'method': 'DDM',
#  'avg_accuracy': 98.66793333333334,
#  'std_accuracy': 0.11734973762024384,
#  'avg_cpu': 44.34340836666667,
#  'std_cpu': 1.8448637353638306,
#  'avg_ram': 2.7647761323385662e-08,
#  'std_ram': 1.1535152673193806e-09,
#  'avg_delay': 13342.52777777778,
#  'std_delay': 4446.376039422511,
#  'avg_fp': 6.8,
#  'std_fp': 1.9731531449264992,
#  'avg_tp': 3.433333333333333,
#  'std_tp': 0.4955356249106169}

# %% [markdown]
# ### EDDM

# %%
method = "EDDM"
itt = 0
name = method
eddm_gradual_output = identify_metrics(method, n_itt, name, itt, True, True, True, True)
eddm_gradual_output
# Out:
# {'method': 'EDDM',
#  'avg_accuracy': 98.8317,
#  'std_accuracy': 0.05540829640356043,
#  'avg_cpu': 41.22274026666666,
#  'std_cpu': 1.6061479862049892,
#  'avg_ram': 2.041124541353859e-08,
#  'std_ram': 7.958766613375893e-10,
#  'avg_delay': 6752.5055555555555,
#  'std_delay': 4749.241380548043,
#  'avg_fp': 13.433333333333334,
#  'std_fp': 3.904555743686541,
#  'avg_tp': 3.7,
#  'std_tp': 0.45825756949558405}

# %% [markdown]
# ### STEPD

# %%
method = "STEPD"
itt = 0
name = method
stepd_gradual_output = identify_metrics(method, n_itt, name, itt, True, True, True, True)
stepd_gradual_output
# Out:
# {'method': 'STEPD',
#  'avg_accuracy': 98.78156666666668,
#  'std_accuracy': 0.07989893760173007,
#  'avg_cpu': 43.88048993333334,
#  'std_cpu': 1.9627818872621259,
#  'avg_ram': 2.8652102165268877e-08,
#  'std_ram': 1.2820885774117493e-09,
#  'avg_delay': 6521.005555555556,
#  'std_delay': 4175.754582614787,
#  'avg_fp': 14.066666666666666,
#  'std_fp': 3.6233808644536514,
#  'avg_tp': 3.7,
#  'std_tp': 0.45825756949558405}

# %% [markdown]
# ### EWMAChartDM

# %%
method = "EWMAChartDM"
itt = 0
name = method
EWMAChartDM_gradual_output = identify_metrics(method, n_itt, name, itt, True, True, True, True)
EWMAChartDM_gradual_output
# Out:
# {'method': 'EWMAChartDM',
#  'avg_accuracy': 98.70586666666667,
#  'std_accuracy': 0.07380623902855613,
#  'avg_cpu': 44.22411726666667,
#  'std_cpu': 1.4225201403011527,
#  'avg_ram': 2.5397396985372406e-08,
#  'std_ram': 8.169148529548875e-10,
#  'avg_delay': 7594.169444444445,
#  'std_delay': 4938.474049045326,
#  'avg_fp': 18.633333333333333,
#  'std_fp': 2.344970978261541,
#  'avg_tp': 3.6,
#  'std_tp': 0.48989794855663565}

# %%
method = "moa.classifiers.rules.core.changedetection.NoChangeDetection"
itt = 0
name = "No Drift Detector"
no_output = identify_metrics(method, n_itt, name, itt, True, True, True, True)
no_output
# Out:
# /Users/mauro.dalleluccatosi/Documents/environments/tensair/lib/python3.9/site-packages/numpy/core/_methods.py:269: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /Users/mauro.dalleluccatosi/Documents/environments/tensair/lib/python3.9/site-packages/numpy/core/_methods.py:226: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# /Users/mauro.dalleluccatosi/Documents/environments/tensair/lib/python3.9/site-packages/numpy/core/_methods.py:261: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# {'method': 'moa.classifiers.rules.core.changedetection.NoChangeDetection',
#  'avg_accuracy': 66.30786666666667,
#  'std_accuracy': 0.15868201413265123,
#  'avg_cpu': 41.26179326666667,
#  'std_cpu': 2.0805981464272096,
#  'avg_ram': 1.9299363471017287e-08,
#  'std_ram': 9.73152793605944e-10,
#  'avg_delay': 0,
#  'std_delay': nan,
#  'avg_fp': 0.0,
#  'std_fp': 0.0,
#  'avg_tp': 0.0,
#  'std_tp': 0.0}
