# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Run experiments
#
# cd OPTWIN_PATH/Moa-Experiments/scripts/
#
# ./classification_experiments.sh

# %%
pd.options.mode.chained_assignment = None  # default='warn'

# %%
OPTWIN_PATH = "" #<-- DEFINE OPTWIN PATH
RESULT_FILE1 = OPTWIN_PATH+"/MOA-Experiments/results/nb_results/"
RESULT_FILE1 += "naive_bayes_Electricity_"
RESULT_FILE2 = ".csv"

# %%
def plot_drifts(method, df, drifts_identified):
    df['classifications_correct_(percent)']
    
    plt.figure()
    plt.title(method)
    plt.ylabel('Accuracy') 
    plt.xlabel('Stream datapoints') 
    
    for tp in drifts_identified:
        plt.vlines(tp, 68, 100, colors = "blue", linewidth=0.5, linestyles = "dashed")
        #plt.text(d+500, 80, "Drift", c = "blue", fontsize = 10)
    
    if len(drifts_identified) > 0 : plt.vlines(drifts_identified[0], 68, 100, colors = "blue", linewidth=0.5, linestyles = "dashed", label = "Drifts Identified")

    plt.legend()

    df['classifications_correct_(percent)'].plot()

# %%
def identify_metrics(method):  
    output = {}
    output['method'] = method
    #open n_itt results
    drift_detection = []
    RESULT_FILE = RESULT_FILE1+method+RESULT_FILE2
    df = pd.read_csv(RESULT_FILE, low_memory=False)
    df.columns = [c.replace(' ', '_') for c in df.columns] #remove spaces from column names
    
    df = df.drop('Kappa_Statistic_(percent)', axis=1) #remove unused statistic
    df = df.drop('Kappa_Temporal_Statistic_(percent)', axis=1) #remove unused statistic
    df = df.drop('Kappa_M_Statistic_(percent)', axis=1) #remove unused statistic

    output['accuracy'] = df['classifications_correct_(percent)'][len(df.index)-1]
    output['cpu'] = df['evaluation_time_(cpu_seconds)'][len(df.index)-1]
    output['ram']  = df['model_cost_(RAM-Hours)'][len(df.index)-1]
    output['drifts'] = df['Change_detected'].sum()
    
    drifts_identified = df['Change_detected'].eq(1).index[df['Change_detected'].eq(1)].tolist()
    
    plot_drifts(method, df, drifts_identified)
    
    return output

# %% [markdown]
# ### OPTWIN -r 0.1

# %%
method = "(OPTWIN-r0.1)"
optwin01_output = identify_metrics(method)
optwin01_output
# Out:
# {'method': '(OPTWIN-r0.1)',
#  'accuracy': 79.99426200564972,
#  'cpu': 15.002236,
#  'ram': 1.5878030763315183e-08,
#  'drifts': 68.0}

# %% [markdown]
# ### OPTWIN -r 0.5

# %%
method = "(OPTWIN-r0.5)"
optwin05_output = identify_metrics(method)
optwin05_output
# Out:
# {'method': '(OPTWIN-r0.5)',
#  'accuracy': 83.29802259887006,
#  'cpu': 16.955075,
#  'ram': 1.7937285146779175e-08,
#  'drifts': 158.0}

# %% [markdown]
# ### OPTWIN -r 1.0

# %%
method = "(OPTWIN-r1.0)"
optwin10_output = identify_metrics(method)
optwin10_output
# Out:
# {'method': '(OPTWIN-r1.0)',
#  'accuracy': 82.95815677966102,
#  'cpu': 16.391667,
#  'ram': 1.7359623070805953e-08,
#  'drifts': 116.0}

# %% [markdown]
# ### ADWIN

# %%
method = "ADWINChangeDetector"
adwin_output = identify_metrics(method)
adwin_output
# Out:
# {'method': 'ADWINChangeDetector',
#  'accuracy': 80.01191737288136,
#  'cpu': 10.087352,
#  'ram': 9.643012997176263e-09,
#  'drifts': 53.0}

# %% [markdown]
# ### DDM

# %%
method = "DDM"
ddm_output = identify_metrics(method)
ddm_output
# Out:
# {'method': 'DDM',
#  'accuracy': 81.1771716101695,
#  'cpu': 10.467339,
#  'ram': 7.414377126840415e-09,
#  'drifts': 143.0}

# %% [markdown]
# ### EDDM

# %%
method = "EDDM"
eddm_output = identify_metrics(method)
eddm_output
# Out:
# {'method': 'EDDM',
#  'accuracy': 84.82962570621469,
#  'cpu': 9.58981,
#  'ram': 5.5387193895875306e-09,
#  'drifts': 203.0}

# %% [markdown]
# ### STEPD

# %%
method = "STEPD"
stepd_output = identify_metrics(method)
stepd_output
# Out:
# {'method': 'STEPD',
#  'accuracy': 84.4919668079096,
#  'cpu': 10.466448,
#  'ram': 7.707132552234305e-09,
#  'drifts': 193.0}

# %% [markdown]
# ### EWMAChartDM

# %%
method = "EWMAChartDM"
EWMAChartDM_output = identify_metrics(method)
EWMAChartDM_output
# Out:
# {'method': 'EWMAChartDM',
#  'accuracy': 86.75847457627118,
#  'cpu': 13.576514,
#  'ram': 8.926753683222048e-09,
#  'drifts': 426.0}

# %%
method = "moa.classifiers.rules.core.changedetection.NoChangeDetection"
stepd_output = identify_metrics(method)
stepd_output
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# {'method': 'moa.classifiers.rules.core.changedetection.NoChangeDetection',
#  'accuracy': 73.36246468926554,
#  'cpu': 9.528662,
#  'ram': 5.265370886772621e-09,
#  'drifts': 0.0}
